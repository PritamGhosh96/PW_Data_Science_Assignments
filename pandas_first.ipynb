# %% [markdown]
# ###### Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %%
import pandas as pd
import numpy as np

series = pd.Series(np.array([4,8,15,16,23,42]))
series
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int32

# %% [markdown]
# ###### Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the variable print it.

# %%
l = [1, 2.0, '4', 'Five', {6 : 7}, 8.9, 10]

# %%
pd.Series(l)
# Out:
# 0         1
# 1       2.0
# 2         4
# 3      Five
# 4    {6: 7}
# 5       8.9
# 6        10
# dtype: object

# %% [markdown]
# ###### Q3. Create a Pandas DataFrame that contains the following data:

# %%
data = {'Name': ['Alice', 'Bob', 'Claire'], 'Age': [25, 30, 27], 'Gender' : ['Female','Male','Female']}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %% [markdown]
# ###### Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.

# %% [markdown]
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames. Series is like a column, a DataFrame is the whole table.

# %% [markdown]
# For Example, Take the above DataFrame df. Each column in the df is a Series.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ###### Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can you give an example of when you might use one of these functions?

# %% [markdown]
# read_csv() : read_csv() function helps read a comma-separated values (csv) file into a Pandas DataFrame.

# %%
df = pd.read_csv("titanic_data.csv")

# %% [markdown]
# head(): Print first 5 row of the dataframe

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# tail(): Print last 5 row of the dataframe

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# describe(): it is used to generate descriptive statistics of the data in a Pandas DataFrame or Series.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# memory_usage() : it returns a Pandas Series having the memory usage of each column (in bytes) in a Pandas DataFrame.

# %%
df.memory_usage(deep = True)
# Out:
# Index            128
# PassengerId     7128
# Survived        7128
# Pclass          7128
# Name           74813
# Sex            54979
# Age             7128
# SibSp           7128
# Parch           7128
# Ticket         56802
# Fare            7128
# Cabin          34344
# Embarked       51626
# dtype: int64

# %% [markdown]
# loc[:] : it helps to access a group of rows and columns in a dataset, a slice of the dataset, as per our requirement.

# %%
df.loc[3:6:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#    Ticket     Fare Cabin Embarked
# 3  113803  53.1000  C123        S
# 5  330877   8.4583   NaN        Q

# %% [markdown]
# groupby() : it is used to group a Pandas DataFrame by 1 or more columns, and perform some mathematical operation on it. groupby() can be used to summarize data in a simple manner.

# %%
df.groupby(by = 'Pclass').Fare.mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# sort_values(): it is used to sort column in a Pandas DataFrame (or a Pandas Series) by values in ascending or descending order.

# %%
df.sort_values( by = 'Fare', inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values( by = 'PassengerId', inplace=True )

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# apply(): The Pandas apply() function can be used to apply a function on every value in a column or row of a DataFrame, and transform that column or row to the resulting values.

# %%
df.Fare = df.Fare.apply(lambda x : x*100)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ###### Q6. Which of the following is mutable in nature Series, DataFrame, Panel?

# %% [markdown]
# There are 3 data structures provided by the Pandas module, which are as follows: Series: It is a 1-D size-immutable array like structure having homogeneous data. DataFrames: It is a 2-D size-mutable tabular structure with heterogeneously typed columns. Panel: It is a 3-D, size-mutable array.

# %% [markdown]
# ###### Q7. Create a DataFrame using multiple Series. Explain with an example.

# %%
courses = pd.Series(["Spark","PySpark","Hadoop"], name = 'courses')
fees = pd.Series([22000,25000,23000], name = "fees")
discount  = pd.Series([1000,2300,1000], name = 'discount')

# Combine two series.
df=pd.concat([courses,fees],axis=1)
print(df)

# It also supports to combine multiple series.
df=pd.concat([courses,fees,discount],axis=1)
print(df)
# Out:
#    courses   fees
# 0    Spark  22000
# 1  PySpark  25000
# 2   Hadoop  23000
#    courses   fees  discount
# 0    Spark  22000      1000
# 1  PySpark  25000      2300
# 2   Hadoop  23000      1000
